# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
sns.set(font_scale=1.3)
sns.set_style('ticks')
colors = ['#0a1ff5', '#3ec154', '#df0b0d', '#aaa205']
sns.set_palette(sns.color_palette(colors))

# %% [markdown]
# ### Read in data

# %%
data = pd.read_csv('plot_Data.csv', index_col=False)
display(data)
# Out:
#        A_x   A_y   B_x   B_y  DA_x  DA_y  DB_x  DB_y
# 0        0   329     0   309     0     0     0     0
# 1        1   300     1   272     1    29     1    37
# 2        2   275     2   246     2    51     2    62
# 3        3   253     3   225     3    71     3    79
# 4        4   217     4   203     4    93     4    94
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 1049  1049  1447  1049  1182  1049  3913  1049  3406
# 1050  1050  1394  1050  1225  1050  3915  1050  3390
# 1051  1051  1435  1051  1246  1051  3909  1051  3389
# 1052  1052  1431  1052  1206  1052  3913  1052  3410
# 1053  1053  1443  1053  1195  1053  3918  1053  3412
#
# [1054 rows x 8 columns]

# %% [markdown]
# ### Plot densities

# %%
fig, ax = plt.subplots()
ax.plot(t, A, label='A')
ax.plot(t, B, label='B')
ax.plot(t, DA, label='DA')
ax.plot(t, DB, label='DB')
ax.set_xlabel('time')
ax.set_ylabel('density')
# ax.set_xlim(0,1000)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
